# %%
import pandas as pd

# %%
data = pd.read_csv('../data/raw/motos_raw.csv', index_col=False)

# %%
data['version'] = data['product'].str.split(' ').str[2:5].str.join(' ')

# %%
{make: list(data[data['vehicle_make']==make]['vehicle_line'].unique()) for make in data['vehicle_make'].unique()}
# Out:
# {'Yamaha': ['Mt-03',
#   'N-Max',
#   'Szr',
#   'Fz-250',
#   'Tenere',
#   'Dt',
#   'Yz',
#   'Fz',
#   'R15',
#   'R1',
#   'Xtz',
#   'Tracer',
#   'BWS',
#   'Mt-09',
#   'X-Max',
#   'Mt-15',
#   'Fz-25',
#   'Fz-2.0',
#   'Super-Tenere',
#   'Fazer',
#   'Aerox',
#   'Ybr',
#   'R3',
#   'Xt',
#   'Ycz']}

# %%
{depto: list(data[data['location_state']==depto]['location_city'].unique()) for depto in data['location_state'].unique()}
# Out:
# {'Bogotá D.C.': ['Usaquén',
#   'Puente Aranda',
#   'Suba',
#   'Fontibón',
#   'Chapinero',
#   'Barrios Unidos',
#   'Engativa',
#   'Teusaquillo',
#   'Kennedy',
#   'Martires',
#   'Rafael Uribe Uribe',
#   'Antonio Nariño',
#   'Tunjuelito',
#   'Bosa',
#   'Ciudad Bolívar',
#   'Usme',
#   'San Cristobal Sur',
#   'Santa Fe',
#   'La Candelaria'],
#  'Cundinamarca': ['Chía',
#   'Cota',
#   'La Calera',
#   'Facatativá',
#   'Soacha',
#   'Mosquera',
#   'Cajicá',
#   'Tabio',
#   'Cáqueza',
#   'Funza',
#   'Fusagasugá',
#   'Tenjo',
#   'Madrid',
#   'Zipaquirá',
#   'Villeta',
#   'La Vega',
#   'Tocancipá',
#   'Sopó',
#   'Bogota',
#   'Susa',
#   'Sasaima',
#   'Sibaté'],
#  'Antioquia': ['Envigado',
#   'La Estrella',
#   'Medellín',
#   'Sabaneta',
#   'Bello',
#   'Girardota',
#   'Retiro',
#   'Itaguí',
#   'El Carmen de Viboral',
#   'Copacabana',
#   'Caldas',
#   'Abejorral',
#   'Caucasia',
#   'La Ceja',
#   'Rionegro',
#   'Gómez Plata'],
# ...

# %%
{depto: list(data[data['location_state']==depto]['location_city'].unique()) for depto in data['location_state'].unique()}
# Out:
# array([1954, 1966, 1971, 1977, 1980, 1981, 1982, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023, 2024])

# %%
{line: list(data[data['vehicle_line']==line]['version'].unique()) for line in data['vehicle_line'].unique()}
# Out:
# {'Mt-03': ['',
#   '321cc Soat Y',
#   'Modelo 2018',
#   '320 2018',
#   '2020',
#   '2017',
#   '2022',
#   'Papeles Sep 25',
#   '2019',
#   '2018',
#   'Modelo 2022',
#   '320 2022',
#   'Soat Y Tecno',
#   'Sin Seguro Ni',
#   'Mod 2019',
#   'Modelo 2017',
#   'En Excelente Estado',
#   '2018 Papeles Nuevos',
#   'V2 Abs Full',
#   'Gris Naranja'],
#  'N-Max': ['Max 155',
#   '2021 En Perfecto',
#   'Connect 2023 ',
#   '2021',
#   '2024',
#   'Connected',
#   'Connected At 155',
#   'Blanco',
#   'Connected 155cc /',
#   '2025 Connect Para',
#   '2025, Estado 10/10,',
#   '',
#   'Connected 155 2022',
#   '155 ',
#   'Connect',
#   '155 - Llanta',
#   '155 Connected Modelo',
#   '155 Negro Mate',
#   '155 2022',
#   '2023',
#   'V1 2022',
#   ' Connected 2024',
#   'Connected Modelo 2025',
#   'Connected 155 2023',
#   '2025',
#   'Connect 2025 ',
#   '155 Abs',
#   'Max Connected 2024',
#   'Conected',
#   '150 2020',
#   '155 2021',
#   '155- Modelo 2020',
# ...

# %%
data[data['vehicle_line']=='Cerato']
# Out:
#       Unnamed: 0                           product     price  \
# 91            91               Kia Cerato Forte Sx  36800000
# 185          185                  Kia Cerato Vivro  66000000
# 243          243           Kia Cerato Forte 2.0 Sx  42000000
# 266          266               Kia Cerato Pro 1.6l  46900000
# 284          284                 Kia Cerato 1.6 Sx  45000000
# ...          ...                               ...       ...
# 8818        8818          Kia Cerato Koup 2.0 Koup  35000000
# 8889        8889      Kia Cerato 1.6 Vivro Vibrant  62500000
# 9438        9438        Kia Cerato Pro 1.6l 130 Hp  56000000
# 9454        9454  Kia Cerato 1.6 Vivro Vibrant Aut  63600000
# 9497        9497           Kia Cerato Forte 1.6 Sx  40000000
#
#                                                    link  years  kilometraje  \
# 91    https://carro.mercadolibre.com.co/MCO-24604410...   2011       118500
# 185   https://carro.mercadolibre.com.co/MCO-22176547...   2019        57000
# ...
